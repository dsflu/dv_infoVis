# %%
import pandas as pd
df2 = pd.read_excel('gtd_12to15_0616dist.xlsx', encoding='utf8')
df1 = pd.read_excel('gtd_92to11_0616dist.xlsx', encoding='utf8')
df =pd.concat([df1,df2])


# def filter_level(nkill,nwound)
#     if nkill > 100:
#         return True
#     else:
#         return False

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  199201000001   1992       1     0        NaN         0        NaN      185
# 1  199201000003   1992       1     0        NaN         0        NaN      604
# 2  199201010001   1992       1     1        NaN         0        NaN       97
# 3  199201010002   1992       1     1        NaN         0        NaN       61
# 4  199201010003   1992       1     1        NaN         0        NaN      603
#
#       country_txt  region                    ...                    addnotes  \
# 0           Spain       8                    ...                         NaN
# 1           Zaire      11                    ...                         NaN
# 2          Israel      10                    ...                         NaN
# 3     El Salvador       2                    ...                         NaN
# 4  United Kingdom       8                    ...                         NaN
#
#   scite1 scite2  scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 0    NaN    NaN     NaN      PGIS       -9        -9        0      -9
# 1    NaN    NaN     NaN      PGIS        1         1        0       1
# 2    NaN    NaN     NaN      PGIS        1         0        0       1
# 3    NaN    NaN     NaN      PGIS        0         1        1       1
# 4    NaN    NaN     NaN      PGIS        0         0        1       1
#
#                                     related
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  199201010004, 199201010005, 199201010006
#
# [5 rows x 137 columns]

# %%
ratio_kill = 0.6
ratio_wound = 1.0 - ratio_kill

df["level"] = df.nkill*ratio_kill + df.nwound*ratio_wound
mask = df.level > 20

# %%
df['time'] = df.apply(lambda x : str(x['iyear'])+'-'+str(x['imonth'])+'-'+str(x['iday'])+' 00:00:00',axis=1)
df['year_m'] = df.apply(lambda x : x['iyear']+x['imonth']/12,axis=1)
df.time.head()
df_new = df[mask]

# %%
filter_data = ["eventid",'time','year_m',"iyear","imonth","iday","region","country_txt","city","latitude","longitude","attacktype1","targtype1","nkill","nwound","level"]
df_filter = df_new[filter_data]
df_filter.tail(20)
# Out:
#             eventid                 time       year_m  iyear  imonth  iday  \
# 50577  201511180051  2015-11-18 00:00:00  2015.916667   2015      11    18
# 50927  201511270029  2015-11-27 00:00:00  2015.916667   2015      11    27
# 51178  201512040023   2015-12-4 00:00:00  2016.000000   2015      12     4
# 51206  201512050008   2015-12-5 00:00:00  2016.000000   2015      12     5
# 51207  201512050009   2015-12-5 00:00:00  2016.000000   2015      12     5
# 51208  201512050010   2015-12-5 00:00:00  2016.000000   2015      12     5
# 51211  201512050013   2015-12-3 00:00:00  2016.000000   2015      12     3
# 51280  201512080014   2015-12-8 00:00:00  2016.000000   2015      12     8
# 51390  201512110026  2015-12-11 00:00:00  2016.000000   2015      12    11
# 51391  201512110027  2015-12-11 00:00:00  2016.000000   2015      12    11
# 51392  201512110028  2015-12-11 00:00:00  2016.000000   2015      12    11
# 51422  201512120033  2015-12-12 00:00:00  2016.000000   2015      12    12
# 51423  201512120034  2015-12-12 00:00:00  2016.000000   2015      12    12
# 51440  201512130006  2015-12-13 00:00:00  2016.000000   2015      12    13
# 51972  201512270043  2015-12-27 00:00:00  2016.000000   2015      12    27
# 52011  201512280026  2015-12-28 00:00:00  2016.000000   2015      12    28
# 52012  201512280027  2015-12-28 00:00:00  2016.000000   2015      12    28
# 52017  201512280032  2015-12-28 00:00:00  2016.000000   2015      12    28
# 52018  201512280033  2015-12-28 00:00:00  2016.000000   2015      12    28
# 52038  201512290001  2015-12-29 00:00:00  2016.000000   2015      12    29
#
#        region  country_txt        city   latitude  longitude  attacktype1  \
# 50577      11      Nigeria        Kano  12.002179   8.591956            3
# 50927      11      Nigeria    Dakasoye  12.002179   8.591956            3
# 51178       9      Ukraine    Maiorska  48.395851  37.974542            9
# 51206      11         Chad    Koulfoua  13.003044  14.738038            3
# 51207      11         Chad    Koulfoua  13.003044  14.738038            3
# 51208      11         Chad    Koulfoua  13.003044  14.738038            3
# 51211       6  Afghanistan  Qala-e Naw  30.560553  63.716010            2
# 51280       6  Afghanistan    Kandahar  31.497145  65.838674            5
# 51390      11      Burundi   Bujumbura  -3.410840  29.375884            2
# 51391      11      Burundi   Bujumbura  -3.352512  29.362799            2
# 51392      11      Burundi    Mujejuru  -3.481207  29.551710            2
# 51422      10        Syria        Homs  34.733526  36.733118            3
# 51423      10        Syria        Homs  34.733661  36.732997            3
# 51440       6     Pakistan  Parachinar  33.905705  70.100966            3
# 51972      11      Nigeria   Maiduguri  11.831098  13.150967            3
# 52011      10        Syria        Homs  34.733661  36.732997            3
# 52012      10        Syria        Homs  34.733661  36.732997            3
# 52017      11      Nigeria    Madagali  10.891605  13.627317            3
# 52018      11      Nigeria   Maiduguri  11.831098  13.150967            3
# 52038       6     Pakistan      Mardan  34.200114  72.050801            3
#
#        targtype1  nkill  nwound  level
# 50577         14    8.0    61.0   29.2
# 50927         14   22.0    38.0   28.4
# 51178          4   20.0    30.0   24.0
# 51206         14    7.0    44.0   21.8
# 51207         14    6.0    43.0   20.8
# 51208         14    6.0    43.0   20.8
# 51211          4   30.0    15.0   24.0
# 51280          4   73.0    37.0   58.6
# 51390          4   29.0     7.0   20.2
# 51391          4   29.0     7.0   20.2
# 51392          4   29.0     7.0   20.2
# 51422         14   11.0    35.0   20.6
# 51423         14   12.0    35.0   21.2
# 51440         14   22.0    70.0   41.2
# 51972          1   21.0    50.0   32.6
# 52011         14   16.0    45.0   27.6
# 52012         14   17.0    45.0   28.2
# 52017         14   30.0    16.0   24.4
# 52018         15   30.0    65.0   44.0
# 52038          2   27.0    51.0   36.6

# %%
df_filter.to_csv('dv_data.csv', encoding='utf8', index=True,index_label="case")
