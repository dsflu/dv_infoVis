# %%
import pandas as pd
df2 = pd.read_excel('gtd_12to15_0616dist.xlsx', encoding='utf8')
df1 = pd.read_excel('gtd_92to11_0616dist.xlsx', encoding='utf8')
df =pd.concat([df1,df2])


# def filter_level(nkill,nwound)
#     if nkill > 100:
#         return True
#     else:
#         return False

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  199201000001   1992       1     0        NaN         0        NaN      185
# 1  199201000003   1992       1     0        NaN         0        NaN      604
# 2  199201010001   1992       1     1        NaN         0        NaN       97
# 3  199201010002   1992       1     1        NaN         0        NaN       61
# 4  199201010003   1992       1     1        NaN         0        NaN      603
#
#       country_txt  region                    ...                    addnotes  \
# 0           Spain       8                    ...                         NaN
# 1           Zaire      11                    ...                         NaN
# 2          Israel      10                    ...                         NaN
# 3     El Salvador       2                    ...                         NaN
# 4  United Kingdom       8                    ...                         NaN
#
#   scite1 scite2  scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 0    NaN    NaN     NaN      PGIS       -9        -9        0      -9
# 1    NaN    NaN     NaN      PGIS        1         1        0       1
# 2    NaN    NaN     NaN      PGIS        1         0        0       1
# 3    NaN    NaN     NaN      PGIS        0         1        1       1
# 4    NaN    NaN     NaN      PGIS        0         0        1       1
#
#                                     related
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  199201010004, 199201010005, 199201010006
#
# [5 rows x 137 columns]

# %%
ratio_kill = 0.6
ratio_wound = 1.0 - ratio_kill

df["level"] = df.nkill*ratio_kill + df.nwound*ratio_wound
mask = df.level > 20

# %%
df['time'] = df.apply(lambda x : str(x['iyear'])+'-'+str(x['imonth'])+'-'+str(x['iday'])+' 00:00:00',axis=1)
df['year_m'] = df.apply(lambda x : x['iyear']+x['imonth']/12,axis=1)
df.time.head()
df_new = df[mask]
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-900a0c7ca496> in <module>()
#       2 df.time.head()
#       3 df_new = df[mask]
# ----> 4 df_new = df_new[mask2]
#       5 df_new.time.count()
#
# //anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1989         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1990             # either boolean or fancy integer index
# -> 1991             return self._getitem_array(key)
#    1992         elif isinstance(key, DataFrame):
#    1993             return self._getitem_frame(key)
#
# //anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2029             # check_bool_indexer will throw exception if Series key cannot
#    2030             # be reindexed to match DataFrame rows
# -> 2031             key = check_bool_indexer(self.index, key)
#    2032             indexer = key.nonzero()[0]
#    2033             return self.take(indexer, axis=0, convert=False)
#
# //anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in check_bool_indexer(ax, key)
#    1796     result = key
#    1797     if isinstance(key, ABCSeries) and not key.index.equals(ax):
# -> 1798         result = result.reindex(ax)
#    1799         mask = com.isnull(result._values)
#    1800         if mask.any():
#
# //anaconda/lib/python3.5/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    2285     @Appender(generic._shared_docs['reindex'] % _shared_doc_kwargs)
#    2286     def reindex(self, index=None, **kwargs):
# -> 2287         return super(Series, self).reindex(index=index, **kwargs)
#    2288
#    2289     @Appender(generic._shared_docs['fillna'] % _shared_doc_kwargs)
#
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    2227         # perform the reindex on the axes
#    2228         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 2229                                   fill_value, copy).__finalize__(self)
#    2230
#    2231     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    2245             obj = obj._reindex_with_indexers({axis: [new_index, indexer]},
#    2246                                              fill_value=fill_value,
# -> 2247                                              copy=copy, allow_dups=False)
#    2248
#    2249         return obj
#
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    2339                                                 fill_value=fill_value,
#    2340                                                 allow_dups=allow_dups,
# -> 2341                                                 copy=copy)
#    2342
#    2343         if copy and new_data is self._data:
#
# //anaconda/lib/python3.5/site-packages/pandas/core/internals.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    3584         # some axes don't allow reindexing with dups
#    3585         if not allow_dups:
# -> 3586             self.axes[axis]._can_reindex(indexer)
#    3587
#    3588         if axis >= self.ndim:
#
# //anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in _can_reindex(self, indexer)
#    2291         # trying to reindex on an axis with duplicates
#    2292         if not self.is_unique and len(indexer):
# -> 2293             raise ValueError("cannot reindex from a duplicate axis")
#    2294
#    2295     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis

# %%
filter_data = ["eventid",'time',"iyear","imonth","iday","region","country_txt","city","latitude","longitude","attacktype1","targtype1","nkill","nwound","level"]
df_filter = df_new[filter_data]
df_filter.head()
# Out:
#           eventid                time  iyear  imonth  iday  region  \
# 1    199201000003   1992-1-0 00:00:00   1992       1     0      11
# 57   199201060008   1992-1-6 00:00:00   1992       1     6       5
# 198  199201170011  1992-1-17 00:00:00   1992       1    17      11
# 208  199201180009  1992-1-18 00:00:00   1992       1    18      11
# 307  199201260012  1992-1-26 00:00:00   1992       1    26       6
#
#     country_txt                               city   latitude   longitude  \
# 1         Zaire                          Fungurume -10.617413   26.309511
# 57     Cambodia  Stoung and Kompong Svay Districts  12.901934  104.525757
# 198    Djibouti                            Unknown  11.519184   42.262496
# 208    Djibouti                              Kalaf  11.759351   42.791767
# 307   Sri Lanka                        Aranthalawa   7.528000   81.477833
#
#      attacktype1  targtype1  nkill  nwound  level
# 1              2          2    8.0    50.0   24.8
# 57             3         14   13.0    32.0   20.6
# 198            2          4   61.0     9.0   40.2
# 208            2          4  105.0    10.0   67.0
# 307            3         19   13.0    32.0   20.6

# %%
df_filter.to_csv('dv_data.csv', encoding='utf8', index=True,index_label="case")
